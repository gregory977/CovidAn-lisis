# %% [markdown]
# <a href="https://colab.research.google.com/github/gregory977/CovidEstudio/blob/main/Casos_de_covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Observatorio: Evolución del comportamiento del Covid en Boyacá y Cundinamarca
# Por: Gregory Ahumada

# %%
# Importartación y subida de archivo
import pandas as pd

ruta_archivo = '/content/Casos_positivos_de_COVID-19-Cund-Boy.csv'

df = pd.read_csv(ruta_archivo)

#Revisión
df.head()
# Out:
#   id_case;id_municipality;name_municipality;id_department;name_department;age;gender;type_contagion;status;date_symptom;date_death;date_diagnosis;date_recovery
# 0  489982;25;CUNDINAMARCA;25899;ZIPAQUIRA;22;F;Co...
# 1  5932109;25;CUNDINAMARCA;25758;SOPO;50;M;Comuni...
# 2  3036330;25;CUNDINAMARCA;25099;BOJACA;67;M;Comu...
# 3  1788659;25;CUNDINAMARCA;25151;CAQUEZA;51;F;Rel...
# 4  4715565;25;CUNDINAMARCA;25290;FUSAGASUGA;40;M;...

# %%
#Revisión y estadísticas archivo
info_df = df.info()
descripcion_estadistica = df.describe()

#Valores
valores_unicos = df.nunique()

# Nulls
valores_nulos = df.isnull().sum()

# Mostrar las primeras filas del DataFrame
primeras_filas = df.head()

#
print("Información general del DataFrame:")
print(info_df)
print("\nEstadísticas descriptivas:")
print(descripcion_estadistica)
print("\nValores únicos por columna:")
print(valores_unicos)
print("\nCantidad de valores nulos por columna:")
print(valores_nulos)
print("\nPrimeras filas del DataFrame:")
print(primeras_filas)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                         --------------  -----
#  0   id_case;id_municipality;name_municipality;id_department;name_department;age;gender;type_contagion;status;date_symptom;date_death;date_diagnosis;date_recovery  20000 non-null  object
# dtypes: object(1)
# memory usage: 156.4+ KB
# Información general del DataFrame:
# None
#
# Estadísticas descriptivas:
#        id_case;id_municipality;name_municipality;id_department;name_department;age;gender;type_contagion;status;date_symptom;date_death;date_diagnosis;date_recovery
# ...

# %%
# Reno,brar columnas erradas (Municipios y deptos)
df = df.rename(columns={'name_municipality': 'name_department', 'name_department': 'name_municipality'})

df.head()
# Out:
#   id_case;id_municipality;name_municipality;id_department;name_department;age;gender;type_contagion;status;date_symptom;date_death;date_diagnosis;date_recovery
# 0  489982;25;CUNDINAMARCA;25899;ZIPAQUIRA;22;F;Co...
# 1  5932109;25;CUNDINAMARCA;25758;SOPO;50;M;Comuni...
# 2  3036330;25;CUNDINAMARCA;25099;BOJACA;67;M;Comu...
# 3  1788659;25;CUNDINAMARCA;25151;CAQUEZA;51;F;Rel...
# 4  4715565;25;CUNDINAMARCA;25290;FUSAGASUGA;40;M;...

# %%
##Revisar de nuevo archivo csv, caracteres y delimitación y columnas

import pandas as pd

ruta_archivo = '/content/Casos_positivos_de_COVID-19-Cund-Boy.csv'

df = pd.read_csv(ruta_archivo, delimiter=';')
print(df.columns)
# Out:
# Index(['id_case', 'id_municipality', 'name_municipality', 'id_department',
#        'name_department', 'age', 'gender', 'type_contagion', 'status',
#        'date_symptom', 'date_death', 'date_diagnosis', 'date_recovery'],
#       dtype='object')

# %%
# Crear tablas para el modelo de datos##
municipality = df[['id_case', 'id_department', 'name_municipality', 'id_municipality']]

department = df[['id_case', 'id_department']]

gender = df[['id_case', 'gender']]

type_contagion = df[['id_case', 'type_contagion']]

estatus = df[['id_case', 'status']]

##Descargas para usar en Power BI
municipality.to_csv('/content/hoja_municipality.csv', index=False)
department.to_csv('/content/hoja_department.csv', index=False)
gender.to_csv('/content/hoja_gender.csv', index=False)
type_contagion.to_csv('/content/hoja_type_contagion.csv', index=False)
estatus.to_csv('/content/hoja_status.csv', index=False)
